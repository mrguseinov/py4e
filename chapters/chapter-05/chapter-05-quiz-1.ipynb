# %% [markdown]
# **DO NOT EDIT THE CODE IN THIS FILE**

# %%
# %reset -f

from sys import path
path.append("../../")

from helpers.submitters import QuizSubmitter
from helpers.widgets import MyCheckBoxes, MyRadioButtons

questions = [MyRadioButtons(4) for _ in range(10)]
questions[7] = MyCheckBoxes(4)

submitter = QuizSubmitter("05.1")

# %% [markdown]
# <hr>
#
# ### Question 0
#
# What is **wrong** with the following loop?
#
# ```python
# n = 5
# while n > 0:
#     print(n)
# print("All done")
# ```
#
# 1. This loop will run forever.
# 2. The `print("All done")` statement should be indented four spaces.
# 3. There should be no colon `:` on the `while` statement.
# 4. `while` is not a Python keyword.

# %%
questions[0].show()

# %% [markdown]
# <hr>
#
# ### Question 1
#
# What does the `break` statement do?
#
# 1. Jumps to the "top" of the loop and starts the next iteration.
# 2. Exits the currently executing loop.
# 3. Exits the program.
# 4. Pauses the currently executing loop.

# %%
questions[1].show()

# %% [markdown]
# <hr>
#
# ### Question 2
#
# What does the `continue` statement do?
#
# 1. Pauses the currently executing loop.
# 2. Jumps to the "top" of the loop and starts the next iteration.
# 3. Exits the currently executing loop.
# 4. Exits the program.

# %%
questions[2].show()

# %% [markdown]
# <hr>
#
# ### Question 3
#
# What will the following code print out?
#
# ```python
# count = 0
# for _ in [5, 4, 3, 2, 1]:
#     count += 1
# print(count)
# ```
#
# 1. `10`
# 2. `0`
# 3. `15`
# 4. `5`

# %%
questions[3].show()

# %% [markdown]
# <hr>
#
# ### Question 4
#
# How many iterations does the following loop perform?
#
# ```python
# friends = ["Joseph", "Glenn", "Sally"]
# for friend in friends:
#     print(f"Happy New Year: {friend}!")
# print("Done!")
# ```
#
# 1. `3`
# 2. `4`
# 3. `2`
# 4. `1`

# %%
questions[4].show()

# %% [markdown]
# <hr>
#
# ### Question 5
#
# What is a good description of the following bit of code?
#
# ```python
# total = 0
# for value in [9, 41, 12, 3, 74, 15]:
#     total += value
# print(total)
# ```
#
# 1. Find the smallest value in the list.
# 2. Count all the values in the list.
# 3. Find the largest value in the list.
# 4. Sum all the values in the list.

# %%
questions[5].show()

# %% [markdown]
# <hr>
#
# ### Question 6
#
# What will the following code print out?
#
# ```python
# smallest = -1
# for number in [9, 41, 12, 3, 74, 15]:
#     if number < smallest:
#         smallest = number
# print(smallest)
# ```
#
# *Hint: This is a trick question and most would say this code has a bug — so read carefully.*
#
# 1. `-1`
# 2. `74`
# 3. `42`
# 4. `3`

# %%
questions[6].show()

# %% [markdown]
# <hr>
#
# ### Question 7
#
# Check all that apply.
#
# 1. The `==` operator compares the values of two objects and checks whether they are equal.
# 2. There is no such operator as `is`.
# 3. The `is` operator checks whether two variables refer to the same object in memory.
# 4. In Python 3, there is no difference between `is` and `==`.

# %%
questions[7].show()

# %% [markdown]
# <hr>
#
# ### Question 8
#
# Which of the following is **not** a control statement in loops?
#
# 1. `break`
# 2. `end`
# 3. `continue`
# 4. None of the above.

# %%
questions[8].show()

# %% [markdown]
# <hr>
#
# ### Question 9
#
# How many times will the body of the following loop be executed?
#
# ```python
# n = 0
# while n > 0:
#     print("Lather")
#     print("Rinse")
# print("Dry off!")
# ```
#
# 1. `0`
# 2. `1`
# 3. `5`
# 4. This is an infinite loop.

# %%
questions[9].show()

# %% [markdown]
# <hr>
#
# ### Submit

# %%
submitter.submit(questions)
